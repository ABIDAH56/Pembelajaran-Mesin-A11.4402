# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Import dataset yang di butuhkan menggunakan pandas**
# Data seat yang saya gunakan dari
# https://www.kaggle.com/mariaren/covid19-healthy-diet-dataset/notebooks

# %%
df_food = pd.read_csv('Food_Supply_Quantity_kg_Data.csv')
df_protein = pd.read_csv('Protein_Supply_Quantity_Data.csv')
df_fat = pd.read_csv('Fat_Supply_Quantity_Data.csv')
df_category = pd.read_csv('Supply_Food_Data_Descriptions.csv')

# %% [markdown]
# **Memeriksa 5 data teratas dari masing masing dataset**

# %%
df_food.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan               0.0014       0.1973           9.4341
# 1              Albania               1.6719       0.1357          18.7684
# 2              Algeria               0.2711       0.0282           9.6334
# 3               Angola               5.8087       0.0560           4.9278
# 4  Antigua and Barbuda               3.5764       0.0087          16.6613
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   24.8097  0.2099         0.0350
# 1                      0.0                    5.7817  0.5815         0.2126
# 2                      0.0                   13.6816  0.5277         0.2416
# 3                      0.0                    9.1085  0.0587         1.7707
# 4                      0.0                    5.9960  0.2274         4.1489
#
#    Fruits - Excluding Wine    Meat  ...  Vegetables  Vegetal Products  \
# 0                   5.3495  1.2020  ...      6.7642           40.5645
# 1                   6.7861  1.8845  ...     11.7753           31.2304
# 2                   6.3801  1.1305  ...     11.6484           40.3651
# 3                   6.0005  2.0571  ...      2.3041           45.0722
# 4                  10.7451  5.6888  ...      5.4495           33.3233
#
#    Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 0      4.5            29.8   0.142134  0.006186   0.123374  0.012574
# 1     22.3             6.2   2.967301  0.050951   1.792636  1.123714
# 2     26.6             3.9   0.244897  0.006558   0.167572  0.070767
# 3      6.8              25   0.061687  0.001461   0.056808  0.003419
# 4     19.1             NaN   0.293878  0.007143   0.190816  0.095918
#
#    Population  Unit (all except Population)
# 0  38928000.0                             %
# 1   2838000.0                             %
# 2  44357000.0                             %
# 3  32522000.0                             %
# 4     98000.0                             %
#
# [5 rows x 32 columns]

# %%
df_protein.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
#    Fruits - Excluding Wine     Meat  ...  Vegetables  Miscellaneous  Obesity  \
# 0                   0.5824   3.1337  ...      1.1370         0.0462      4.5
# 1                   1.2757   7.6582  ...      3.2456         0.0544     22.3
# 2                   1.1624   3.5088  ...      3.1267         0.1399     26.6
# 3                   1.2754   7.6248  ...      0.8133         0.0924      6.8
# 4                   1.2586  16.0670  ...      1.6024         0.2947     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
df_fat.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0          21.6397       6.2224
# 1              Albania                  0.0          32.0002       3.4172
# 2              Algeria                  0.0          14.4175       0.8972
# 3               Angola                  0.0          15.3041       1.3130
# 4  Antigua and Barbuda                  0.0          27.7033       4.6686
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 4                      0.0                    3.2153  0.3872         1.5263
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   0.4246   6.1244  ...         17.0831      0.3593      4.5
# 1                   0.6418   8.7428  ...          9.2443      0.6503     22.3
# 2                   0.5772   3.8961  ...         27.3606      0.5145     26.6
# 3                   0.3488  11.0268  ...         22.4638      0.1231      6.8
# 4                   1.2177  14.3202  ...         14.4436      0.2469     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
df_category.head()
# Out:
#                  Categories                                              Items
# 0       Alcoholic Beverages  Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1               Animal fats  Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2           Animal Products  Aquatic Animals, Others; Aquatic Plants; Bovin...
# 3   Aquatic Products, Other  Aquatic Animals, Others; Aquatic Plants; Meat,...
# 4  Cereals - Excluding Beer  Barley and products; Cereals, Other; Maize and...

# %% [markdown]
# **Memisahkan kolom pada supply dataset antara kategori makanan dan bukan makanan**

# %%
all_columns = df_food.columns.tolist()
print(f'All Columns : {all_columns}\n')

supply_columns = df_category['Categories'].tolist()
print(f'Supply Columns : {supply_columns} \n\n')

non_supply_columns = [i for i in all_columns if i not in supply_columns]
print(f'Non-Supply Columns : {non_supply_columns}')
# Out:
# All Columns : ['Country', 'Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']
#
# Supply Columns : ['Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products']
#
#
# Non-Supply Columns : ['Country', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']

# %% [markdown]
# **Menggabungkan DataFrame**

# %%
df_non_supply_new = df_food[non_supply_columns]
df_food_new = df_food[['Country']+supply_columns]
df_protein_new = df_protein[['Country']+supply_columns]
df_fat_new = df_fat[['Country']+supply_columns]

# %%
import pandas as pd

df1 = pd.merge(df_food_new, df_protein_new, on="Country", suffixes=('_food', '_protein'), how='outer')
df_fat_new_cols = [i + '_fat' if i != 'Country' else i for i in df_fat_new.columns]
df_fat_new.columns = df_fat_new_cols

df2 = pd.merge(df_fat_new, df_non_supply_new, how='outer', on='Country')

# Perbaikan: Gunakan hanya 'on' atau 'index' dalam merge
df3 = pd.merge(df1, df2, how='left', on='Country')

print(df3.columns.tolist())
# Out:
# ['Country', 'Alcoholic Beverages_food', 'Animal fats_food', 'Animal Products_food', 'Aquatic Products, Other_food', 'Cereals - Excluding Beer_food', 'Eggs_food', 'Fish, Seafood_food', 'Fruits - Excluding Wine_food', 'Meat_food', 'Milk - Excluding Butter_food', 'Miscellaneous_food', 'Offals_food', 'Oilcrops_food', 'Pulses_food', 'Spices_food', 'Starchy Roots_food', 'Stimulants_food', 'Sugar & Sweeteners_food', 'Sugar Crops_food', 'Treenuts_food', 'Vegetable Oils_food', 'Vegetables_food', 'Vegetal Products_food', 'Alcoholic Beverages_protein', 'Animal fats_protein', 'Animal Products_protein', 'Aquatic Products, Other_protein', 'Cereals - Excluding Beer_protein', 'Eggs_protein', 'Fish, Seafood_protein', 'Fruits - Excluding Wine_protein', 'Meat_protein', 'Milk - Excluding Butter_protein', 'Miscellaneous_protein', 'Offals_protein', 'Oilcrops_protein', 'Pulses_protein', 'Spices_protein', 'Starchy Roots_protein', 'Stimulants_protein', 'Sugar & Sweeteners_protein', 'Sugar Crops_protein', 'Treenuts_protein', 'Vegetable Oils_protein', 'Vegetables_protein', 'Vegetal Products_protein', 'Alcoholic Beverages_fat', 'Animal fats_fat', 'Animal Products_fat', 'Aquatic Products, Other_fat', 'Cereals - Excluding Beer_fat', 'Eggs_fat', 'Fish, Seafood_fat', 'Fruits - Excluding Wine_fat', 'Meat_fat', 'Milk - Excluding Butter_fat', 'Miscellaneous_fat', 'Offals_fat', 'Oilcrops_fat', 'Pulses_fat', 'Spices_fat', 'Starchy Roots_fat', 'Stimulants_fat', 'Sugar & Sweeteners_fat', 'Sugar Crops_fat', 'Treenuts_fat', 'Vegetable Oils_fat', 'Vegetables_fat', 'Vegetal Products_fat', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']

# %%
df3
# Out:
#                                 Country  Alcoholic Beverages_food  \
# 0                           Afghanistan                    0.0014
# 1                               Albania                    1.6719
# 2                               Algeria                    0.2711
# 3                                Angola                    5.8087
# 4                   Antigua and Barbuda                    3.5764
# ..                                  ...                       ...
# 165  Venezuela (Bolivarian Republic of)                    2.5952
# 166                             Vietnam                    1.4591
# 167                               Yemen                    0.0364
# 168                              Zambia                    5.7360
# 169                            Zimbabwe                    4.0552
#
#      Animal fats_food  Animal Products_food  Aquatic Products, Other_food  \
# 0              0.1973                9.4341                        0.0000
# 1              0.1357               18.7684                        0.0000
# 2              0.0282                9.6334                        0.0000
# 3              0.0560                4.9278                        0.0000
# 4              0.0087               16.6613                        0.0000
# ..                ...                   ...                           ...
# 165            0.0403               14.7565                        0.0000
# 166            0.1640                8.5765                        0.0042
# 167            0.0446                5.7874                        0.0000
# 168            0.0829                6.0197                        0.0000
# 169            0.0755                8.1489                        0.0000
#
#      Cereals - Excluding Beer_food  Eggs_food  Fish, Seafood_food  \
# 0                          24.8097     0.2099              0.0350
# 1                           5.7817     0.5815              0.2126
# 2                          13.6816     0.5277              0.2416
# 3                           9.1085     0.0587              1.7707
# 4                           5.9960     0.2274              4.1489
# ..                             ...        ...                 ...
# 165                        12.9253     0.3389              0.9456
# 166                        16.8740     0.3077              2.6392
# 167                        27.2077     0.2579              0.5240
# 168                        21.1938     0.3399              1.6924
# 169                        22.6240     0.2678              0.5518
#
#      Fruits - Excluding Wine_food  Meat_food  ...  Vegetables_fat  \
# 0                          5.3495     1.2020  ...          0.3593
# 1                          6.7861     1.8845  ...          0.6503
# 2                          6.3801     1.1305  ...          0.5145
# 3                          6.0005     2.0571  ...          0.1231
# 4                         10.7451     5.6888  ...          0.2469
# ..                            ...        ...  ...             ...
# 165                        7.6460     3.8328  ...          0.1851
# 166                        5.9029     4.4382  ...          0.6373
# 167                        5.1344     2.7871  ...          0.1667
# 168                        1.0183     1.8427  ...          0.1567
# 169                        2.2000     2.6142  ...          0.0789
#
#      Vegetal Products_fat  Obesity  Undernourished  Confirmed    Deaths  \
# 0                 28.3684      4.5            29.8   0.142134  0.006186
# 1                 17.9998     22.3             6.2   2.967301  0.050951
# 2                 35.5857     26.6             3.9   0.244897  0.006558
# 3                 34.7010      6.8              25   0.061687  0.001461
# 4                 22.2995     19.1             NaN   0.293878  0.007143
# ..                    ...      ...             ...        ...       ...
# 165               33.6855     25.2            21.2   0.452585  0.004287
# 166               16.7548      2.1             9.3   0.002063  0.000036
# 167               37.4535     14.1            38.9   0.007131  0.002062
# 168               40.3939      6.5            46.7   0.334133  0.004564
# 169               39.6248     12.3            51.3   0.232033  0.008854
#
#      Recovered    Active  Population  Unit (all except Population)
# 0     0.123374  0.012574  38928000.0                             %
# 1     1.792636  1.123714   2838000.0                             %
# 2     0.167572  0.070767  44357000.0                             %
# 3     0.056808  0.003419  32522000.0                             %
# 4     0.190816  0.095918     98000.0                             %
# ..         ...       ...         ...                           ...
# 165   0.424399  0.023899  28645000.0                             %
# 166   0.001526  0.000501  96209000.0                             %
# 167   0.004788  0.000282  29826000.0                             %
# 168   0.290524  0.039045  18384000.0                             %
# 169   0.190964  0.032214  14863000.0                             %
#
# [170 rows x 78 columns]

# %% [markdown]
# **Sorting dan Filtering**

# %%
df_sort = df.sort_values(by=['Deaths'], ascending=False, ignore_index=True)
print(df_sort.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a667db193129> in <cell line: 0>()
# ----> 1 df_sort = df.sort_values(by=['Deaths'], ascending=False, ignore_index=True)
#       2 print(df_sort.head())
#
# NameError: name 'df' is not defined

# %% [markdown]
# Menampilkan Negara Indonesia urutan ke berapa

# %%
indo = list(df_sort[df_sort['Country']== 'Indonesia'].index+1)[0]

print('Indonesia urutan : {}'.format(indo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-fc92da52c0c0> in <cell line: 0>()
# ----> 1 indo = list(df_sort[df_sort['Country']== 'Indonesia'].index+1)[0]
#       2
#       3 print('Indonesia urutan : {}'.format(indo))
#
# NameError: name 'df_sort' is not defined

# %% [markdown]
# **Binning,Grouping,dan Aggreating data**

# %%
labels = ['Sangat Tidak Banyak', 'Tidak Banyak','Sedang','Cukup Banyak','Sangat Banyak']
df_fat ['Confirmed Category']= pd.qcut((df_fat['Confirmed']),5,labels=labels)

# %%
cols = ['Obesity', 'Meat', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products', 'Vegetal Products']

groupby_confirmed = df_fat.groupby('Confirmed Category')[cols].mean()
groupby_confirmed
# Out:
# <ipython-input-20-8775596455e6>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groupby_confirmed = df_fat.groupby('Confirmed Category')[cols].mean()
#                        Obesity       Meat  Fruits - Excluding Wine  \
# Confirmed Category
# Sangat Tidak Banyak  12.156250   9.748312                 0.411312
# Tidak Banyak         12.136364   6.856964                 0.865030
# Sedang               19.243750   9.743353                 0.518112
# Cukup Banyak         24.884848  10.131742                 0.542139
# Sangat Banyak        24.903030  10.415409                 0.411294
#
#                      Fish, Seafood  Animal Products  Vegetal Products
# Confirmed Category
# Sangat Tidak Banyak       0.967479        16.916003         33.084894
# Tidak Banyak              0.960824        15.073282         34.926876
# Sedang                    0.800272        20.315250         29.684997
# Cukup Banyak              0.853700        24.875552         25.124115
# Sangat Banyak             0.558924        26.164791         23.835294

# %%
groupby_confirmed.to_csv('groupby_confirmed.csv')

# %% [markdown]
# **Bar Plot**

# %% [markdown]
# Menggunakan data grouping buat melakukan visualisasi Bar Plot

# %%
df = groupby_confirmed
display(df)
# Out:
#                        Obesity       Meat  Fruits - Excluding Wine  \
# Confirmed Category
# Sangat Tidak Banyak  12.156250   9.748312                 0.411312
# Tidak Banyak         12.136364   6.856964                 0.865030
# Sedang               19.243750   9.743353                 0.518112
# Cukup Banyak         24.884848  10.131742                 0.542139
# Sangat Banyak        24.903030  10.415409                 0.411294
#
#                      Fish, Seafood  Animal Products  Vegetal Products
# Confirmed Category
# Sangat Tidak Banyak       0.967479        16.916003         33.084894
# Tidak Banyak              0.960824        15.073282         34.926876
# Sedang                    0.800272        20.315250         29.684997
# Cukup Banyak              0.853700        24.875552         25.124115
# Sangat Banyak             0.558924        26.164791         23.835294

# %%
df_norm = (df - df.min()) / (df.max() - df.min())
display(df_norm)
# Out:
#                       Obesity      Meat  Fruits - Excluding Wine  \
# Confirmed Category
# Sangat Tidak Banyak  0.001558  0.812531                 0.000040
# Tidak Banyak         0.000000  0.000000                 1.000000
# Sedang               0.556714  0.811138                 0.235420
# Cukup Banyak         0.998576  0.920284                 0.288373
# Sangat Banyak        1.000000  1.000000                 0.000000
#
#                      Fish, Seafood  Animal Products  Vegetal Products
# Confirmed Category
# Sangat Tidak Banyak       1.000000         0.166138          0.833930
# Tidak Banyak              0.983712         0.000000          1.000000
# Sedang                    0.590735         0.472611          0.527400
# Cukup Banyak              0.721509         0.883763          0.116198
# Sangat Banyak             0.000000         1.000000          0.000000

# %%
x = np.arange(len(df_norm.columns))
y = df_norm.loc['Sangat Tidak Banyak']
y1 = df_norm.loc['Tidak Banyak']
y2 = df_norm.loc['Sedang']
y3 = df_norm.loc['Cukup Banyak']
y4 = df_norm.loc['Sangat Banyak']

# %%
fig, ax = plt.subplots(figsize=(14,10))
width = 0.1
a1= ax.bar(x, y, width, label='Sangat Tidak Banyak')
a2= ax.bar(x+0.1, y1, width, label='Tidak Banyak')
a3= ax.bar(x+0.2, y2, width, label='Sedang')
a4= ax.bar(x+0.3, y3, width, label='Cukup Banyak')
a5= ax.bar(x+0.4, y4, width, label='Sangat Banyak')

#menambahkan label
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2, height, str(round(height,2)),
                    ha='center', va='bottom')

autolabel(a1)
autolabel(a2)
autolabel(a3)
autolabel(a4)
autolabel(a5)

plt.xticks(x + 0.2, ('Obesity', 'Meat', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products','Vegetal Products'))
ax.set_title('Perbandingan Konsumsi Makanan Berdasarkan Tingkat Kasus COVID 19')
ax.legend(bbox_to_anchor=(0.95,1.1))

# %% [markdown]
#  menurut visualisasi diatas negara-negara terkonfirmasi covid yang terdata dalam dataset ini menunjukkan tingkat obesitas yang cukup banyak dengan data supply makanan jenis daging-dagingan dan produk hewani yang menunjukkan konsumsi yang cenderung banyak sedangkan konsumsi suppy makanan jenis buah,ikan,seafood dan sayur-sayuran yang cenderung kurang.

# %% [markdown]
# **Seaborn Scatter plot**

# %% [markdown]
# Visualisasi scatter plot (perpaduan seaborn dan matplotlib) dari df_food antara Supply Sayuran ('Vegetal Products') dan persentase terkonfirmasi ('Confirmed') COVID-19.

# %%
fig, ax = plt.subplots(figsize=(18, 12))

V = df_food['Vegetal Products']
C = df_food['Confirmed']
A = df_food['Animal Products']
D = 200000*df_food['Deaths']

map = plt.scatter(V,C, c=A, cmap='plasma', sizes=D)
sns.regplot(x="Vegetal Products", y="Confirmed", data=df_food, scatter=False, color='black');
# axis labeling
ax.set_xlabel('Vegetal Products')
ax.set_ylabel('Confirmed')
ax.set_title('Healthy Food and Covid-19')

fig.colorbar(map)
plt.show()

# %% [markdown]
# pada visualisasi diatas menunjukkan scatter plot jumlah konsumsi produk supply vegetal/sayuran dan kasus yang terkonfirmasi, dari visualisasi ini didapatkan semakin besar jumlah konsumsi vegetal products maka semakin sedikit juga confirmed case nya, point selanjutnya adalah penggunaan kolom death sebagai ukuran poinnya dimana sebakin besar ukuran poin dalam visualisasi scatter semakin besar juga persentasi kematiannya dan yang terakhir yaitu warna point yang menggunakan kolom produk hewani yang juga telah diberikan range perkiraannya dengan cmap
